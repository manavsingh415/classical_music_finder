# %%
import pandas as pd
import collections
import numpy as np
from os import listdir
from os.path import isfile, join
import itertools
import pickle
import audiolazy
pd.set_option('display.max_rows', 100)

# %%
data = pd.read_csv('YCAC-data-1/MozartSlices.csv')

# %%
def sharpify(note):
    number = note[-1]
    note = note[0:-1]
    flats = ['D-', 'E-', 'G-', 'A-', 'B-']
    sharps = ['C#', 'D#', 'F#', 'G#', 'A#']
    try:
        index = flats.index(note)
    except:
        ValueError
        return note + number
    return sharps[index] + number

# test
print(list(map(sharpify,['A1','A-1','B-8','C3', 'D4', 'F#4'])))
# Out:
# ['A1', 'G#1', 'A#8', 'C3', 'D4', 'F#4']

# %%
def parse_chord(chord_string):
    split_strings = chord_string.split(' ')
    split_strings[-1] = split_strings[-1][:len(split_strings[-1])-1]
    return split_strings[1:]

# %%
def get_parsed_chords(chord_string_list):
    parsed_chords = [parse_chord(chord_str) for chord_str in list(chord_string_list)]
    return parsed_chords

# %%
def save_reduced_data(file_name):
    data = pd.read_csv(file_name, encoding= 'latin 1')
    data.drop(inplace= True, columns= ['NormalForm', 'PCsInNormalForm', 'GlobalScaleDegrees',
                                       'LocalTonic', 'LocalMode', 'LocalSDForm_BassSD'])
    data['Chord'] = get_parsed_chords(data['Chord'])
    data.to_csv(file_name)

# %%
def get_file_paths():
    mypaths = ['YCAC-data-3']
    files = []
    for mypath in mypaths:
        files += [mypath + '/' + f for f in listdir(mypath) if isfile(join(mypath, f))]
    return files
file_paths_3 = get_file_paths()

# %%
# Replace all the files with their 'reduced' versions
# for file_path in get_file_paths():
#     print(file_path, 'done')
#     save_reduced_data(file_path)

# Make all chords sharps or naturals (remove all flats)
# for file in file_paths:
#     data = pd.read_csv(file, encoding= 'latin 1')
#     chords = data['Chord']
#     sharpified_chords = [list(map(sharpify, eval(chord))) for chord in chords]
#     data['Chord'] = sharpified_chords
#     data.to_csv(file)
#     print(file, 'completed')

# %%
filename = 'YCAC-data-3/PSlices.csv'
data = pd.read_csv(filename, encoding= 'latin 1')

# %%
# canon_in_d = data[data['file'].str.contains('Canon in D')]

# %%
# canon_in_d.head(100)

# %%
def get_compressed_files():
    for filename in file_paths:
        compressed_filename = filename[0:-4] + '_compressed.csv'
        data = pd.read_csv(filename, encoding= 'latin 1')
        data_pieces = pd.DataFrame(columns= ['Piece Name', 'Chords', 'Composer'])
        piece_starts = data[data['offset'] == 0].copy()
        
        for index, row in piece_starts.iterrows():
            piece_data = data[data['file'] == row['file']].copy()
            chord_list = arrange_chord_lists(piece_data['Chord'])
            piece_starts.at[index, 'Chord'] = chord_list
        piece_starts.drop(columns= ['Unnamed: 0'])
        piece_starts.to_csv(compressed_filename)
        print(filename, 'done')

# %%
def arrange_chord_lists(chords_series):
    output_list = []
    for chordlist in chords_series:
        output_list.append(eval(chordlist))
    return str(output_list)

# %%
data = pd.read_csv('YCAC-data-3/PSlices_compressed.csv')

# %%
# data[(data['file'].str.contains('K331')) & 
#     (data['file'].str.contains('A major'))].head(100)
# data['file'][(data['file'].str.contains('K331'))]

# %%
def get_best_match(chords_series, highest_note_series, notes):
    # Preprocessing to get the required types of lists
    chords_list = list(chords_series)
    chords_list = [eval(chords) for chords in chords_list]
    highest_note_list = list(highest_note_series)
    number_of_notes = len(notes)
    piece_length = len(chords_list)
    if number_of_notes > piece_length:
        return 0
    
    # Moving the notes through the 'windows'
    ending_point = piece_length - number_of_notes + 1
    checked_windows = 0
    matches = []
    while checked_windows < ending_point:
#         print(index)
#         print(chords_list)
        window_chords = chords_list[checked_windows:checked_windows+len(notes)]
        match = check_match(window_chords, notes)
        if match:
            window_highest_notes = [audiolazy.midi2str(num, sharp= True)[:-1] for num in 
                                    highest_note_list[checked_windows:checked_windows+len(notes)]]
            score = score_match(notes, window_highest_notes)
            matches.append(score)
        checked_windows += 1
    if matches:
        return max(matches)
    else:
        return 0

def check_match(chords_list_with_number, notes):
    chords_list = remove_number(chords_list_with_number)
    zip_list = list(zip(notes,chords_list))
    truth_values_list = [note in chords for (note, chords) in zip_list]
    return np.all(truth_values_list)

def remove_number(chords_list):
    f = lambda x: x[0:-1]
    removed_number_list = [list(map(f, chords)) for chords in chords_list]
    return removed_number_list

def score_match(notes, highest_notes):
    zip_list = list(zip(notes, highest_notes))
    score_list = [1 if note == highest_note else 0 for (note, highest_note) in zip_list]
    return float(sum(score_list)) / len(score_list)

# %%
files_by_piece = [(file_name[0:-4] + 'ByPiece', file_name) for file_name in file_paths]
print(files_by_piece)
# Out:
# [('YCAC-data-1/HandelSlicesByPiece', 'YCAC-data-1/HandelSlices.csv'), ('YCAC-data-1/BachSlicesByPiece', 'YCAC-data-1/BachSlices.csv'), ('YCAC-data-1/HaydnSlicesByPiece', 'YCAC-data-1/HaydnSlices.csv'), ('YCAC-data-1/BrahmsSlicesByPiece', 'YCAC-data-1/BrahmsSlices.csv'), ('YCAC-data-1/ChopinSlicesByPiece', 'YCAC-data-1/ChopinSlices.csv'), ('YCAC-data-1/MozartSlicesByPiece', 'YCAC-data-1/MozartSlices.csv'), ('YCAC-data-1/BeethovenSlicesByPiece', 'YCAC-data-1/BeethovenSlices.csv'), ('YCAC-data-1/DebussySlicesByPiece', 'YCAC-data-1/DebussySlices.csv'), ('YCAC-data-1/ByrdSlicesByPiece', 'YCAC-data-1/ByrdSlices.csv'), ('YCAC-data-1/MendelssohnSlicesByPiece', 'YCAC-data-1/MendelssohnSlices.csv'), ('YCAC-data-1/LisztSlicesByPiece', 'YCAC-data-1/LisztSlices.csv'), ('YCAC-data-2/WagnerSlicesByPiece', 'YCAC-data-2/WagnerSlices.csv'), ('YCAC-data-2/TchaikovskySlicesByPiece', 'YCAC-data-2/TchaikovskySlices.csv'), ('YCAC-data-2/Saint-SaensSlicesByPiece', 'YCAC-data-2/Saint-SaensSlices.csv'), ('YCAC-data-2/VivaldiSlicesByPiece', 'YCAC-data-2/VivaldiSlices.csv'), ('YCAC-data-2/SchumannSlicesByPiece', 'YCAC-data-2/SchumannSlices.csv'), ('YCAC-data-2/TelemannSlicesByPiece', 'YCAC-data-2/TelemannSlices.csv'), ('YCAC-data-2/ScarlattiSlicesByPiece', 'YCAC-data-2/ScarlattiSlices.csv'), ('YCAC-data-2/SchubertSlicesByPiece', 'YCAC-data-2/SchubertSlices.csv'), ('YCAC-data-3/LSlicesByPiece', 'YCAC-data-3/LSlices.csv'), ('YCAC-data-3/CSlicesByPiece', 'YCAC-data-3/CSlices.csv'), ('YCAC-data-3/OSlicesByPiece', 'YCAC-data-3/OSlices.csv'), ('YCAC-data-3/JSlicesByPiece', 'YCAC-data-3/JSlices.csv'), ('YCAC-data-3/BSlicesByPiece', 'YCAC-data-3/BSlices.csv'), ('YCAC-data-3/WSlicesByPiece', 'YCAC-data-3/WSlices.csv'), ('YCAC-data-3/ZSlicesByPiece', 'YCAC-data-3/ZSlices.csv'), ('YCAC-data-3/DSlicesByPiece', 'YCAC-data-3/DSlices.csv'), ('YCAC-data-3/ISlicesByPiece', 'YCAC-data-3/ISlices.csv'), ('YCAC-data-3/FSlicesByPiece', 'YCAC-data-3/FSlices.csv'), ('YCAC-data-3/MSlicesByPiece', 'YCAC-data-3/MSlices.csv'), ('YCAC-data-3/HSlicesByPiece', 'YCAC-data-3/HSlices.csv'), ('YCAC-data-3/VSlicesByPiece', 'YCAC-data-3/VSlices.csv'), ('YCAC-data-3/GSlicesByPiece', 'YCAC-data-3/GSlices.csv'), ('YCAC-data-3/ASlicesByPiece', 'YCAC-data-3/ASlices.csv'), ('YCAC-data-3/RSlicesByPiece', 'YCAC-data-3/RSlices.csv'), ('YCAC-data-3/SSlicesByPiece', 'YCAC-data-3/SSlices.csv'), ('YCAC-data-3/NSlicesByPiece', 'YCAC-data-3/NSlices.csv'), ('YCAC-data-3/ESlicesByPiece', 'YCAC-data-3/ESlices.csv'), ('YCAC-data-3/KSlicesByPiece', 'YCAC-data-3/KSlices.csv'), ('YCAC-data-3/PSlicesByPiece', 'YCAC-data-3/PSlices.csv'), ('YCAC-data-3/TSlicesByPiece', 'YCAC-data-3/TSlices.csv'), ('YCAC-data-3/USlicesByPiece', 'YCAC-data-3/USlices.csv'), ('YCAC-data-3/YSlicesByPiece', 'YCAC-data-3/YSlices.csv')]

# %%
def get_pieces(data_csv):
    piece_names = list(set(data_csv['file']))
    pieces_dict = dict.fromkeys(piece_names)
    n = len(piece_names)
    for index, piece in enumerate(piece_names):
        pieces_dict[piece] = data_csv[data_csv['file'] == piece]
    return pieces_dict

def save_pieces():
    files_completed = 0
    files_todo = len(files_by_piece)
    for filename_by_piece, file_name in files_by_piece:
        data_by_pieces = get_pieces(pd.read_csv(file_name, encoding= 'latin 1'))
        f = open(filename_by_piece, 'wb')
        pickle.dump(data_by_pieces, f)
        f.close()
        files_completed += 1
        print(files_completed, 'of', files_todo, 'done')
        
# save_pieces()

# %%
# f = open('YCAC-data-1/BeethovenSlicesByPiece', 'rb')
# obj = pickle.load(f)
# Out:
# ['YCAC-data-1/HandelSlices.csv', 'YCAC-data-1/BachSlices.csv', 'YCAC-data-1/HaydnSlices.csv', 'YCAC-data-1/BrahmsSlices.csv', 'YCAC-data-1/ChopinSlices.csv', 'YCAC-data-1/MozartSlices.csv', 'YCAC-data-1/BeethovenSlices.csv', 'YCAC-data-1/DebussySlices.csv', 'YCAC-data-1/ByrdSlices.csv', 'YCAC-data-1/MendelssohnSlices.csv', 'YCAC-data-1/LisztSlices.csv', 'YCAC-data-2/WagnerSlices.csv', 'YCAC-data-2/TchaikovskySlices.csv', 'YCAC-data-2/Saint-SaensSlices.csv', 'YCAC-data-2/VivaldiSlices.csv', 'YCAC-data-2/SchumannSlices.csv', 'YCAC-data-2/TelemannSlices.csv', 'YCAC-data-2/ScarlattiSlices.csv', 'YCAC-data-2/SchubertSlices.csv', 'YCAC-data-3/LSlices.csv', 'YCAC-data-3/CSlices.csv', 'YCAC-data-3/OSlices.csv', 'YCAC-data-3/JSlices.csv', 'YCAC-data-3/BSlices.csv', 'YCAC-data-3/WSlices.csv', 'YCAC-data-3/ZSlices.csv', 'YCAC-data-3/DSlices.csv', 'YCAC-data-3/ISlices.csv', 'YCAC-data-3/FSlices.csv', 'YCAC-data-3/MSlices.csv', 'YCAC-data-3/HSlices.csv', 'YCAC-data-3/VSlices.csv', 'YCAC-data-3/GSlices.csv', 'YCAC-data-3/ASlices.csv', 'YCAC-data-3/RSlices.csv', 'YCAC-data-3/SSlices.csv', 'YCAC-data-3/NSlices.csv', 'YCAC-data-3/ESlices.csv', 'YCAC-data-3/KSlices.csv', 'YCAC-data-3/PSlices.csv', 'YCAC-data-3/TSlices.csv', 'YCAC-data-3/USlices.csv', 'YCAC-data-3/YSlices.csv']

# %%
names_1 = ['Bach', 'Beethoven', 'Brahms', 'Byrd', 'Chopin', 'Debussy', 
          'Handel', 'Haydn', 'Liszt', 'Mendelssohn', 'Mozart']
names_2 = ['Saint-Saens', 'Scarlatti', 'Schubert', 'Schumann', 'Tchaikovsky', 
          'Telemann', 'Vivaldi', 'Wagner']

file_paths_3 = [file for file in file_paths_3 if '.csv' in file]
names_3 = []
for file in file_paths_3:
    data = pd.read_csv(file, encoding= 'latin 1')
    composers = list(set(data['Composer']))
    names_3 = names_3 + composers

# %%
def get_file_path_to_composer(name):
    num = 0
    if name in names_1:
        num = 1
    elif name in names_2:
        num = 2
    elif name in names_3:
        num = 3
    else:
        return False
    return 'YCAC-data-' + str(num) + '/' + name[0] + 'SlicesByPiece'
    
def search_composer(notes, name= 'none'):
    file_name = get_file_path_to_composer(name)
#     matching_compositions = []
    composition_scores = []
    if name:
        file = open(file_name, 'rb')
        data = pickle.load(file)
        if file_name[10] == '3':
            # TODO: get only the data that has the name 'name'
#             data = 
        compositions = list(data)
        for composition in compositions:
            chords_list = data[composition]['Chord']
            highest_notes_list = data[composition]['HighestPitch']
#             if has_notes(chords_list, notes):
#                 matching_compositions.append(composition)
            score = get_best_match(chords_list, highest_notes_list, notes)
            composition_scores.append((composition, score))
    sorted_compositions = sorted(composition_scores, key=lambda x: x[1], reverse= True)
    return sorted_compositions
#     return matching_compositions
    
# found = search_composer(['F#', 'G', 'A', 'B', 'A', 'G', 'A', 'F#', 'G', 'A'], 'Pachelbel')
found = search_composer(['F#', 'G', 'A', 'B', 'A', 'G', 'A', 'F#'], 'Pachelbel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-b964be50d65a> in <module>
#      33
#      34 # found = search_composer(['F#', 'G', 'A', 'B', 'A', 'G', 'A', 'F#', 'G', 'A'], 'Pachelbel')
# ---> 35 found = search_composer(['F#', 'G', 'A', 'B', 'A', 'G', 'A', 'F#'], 'Pachelbel')
#
# <ipython-input-81-b964be50d65a> in search_composer(notes, name)
#      19         data = pickle.load(file)
#      20         if file_name[10] == '3':
# ---> 21             data = data[data['Composer'] == name]
#      22         compositions = list(data)
#      23         for composition in compositions:
#
# KeyError: 'Composer'

# %%
found
# Out:
# [('Violin Concerto in D 1 Allegro Maestoso Op6No1 D major.mid', 1.0),
#  ("Musick's Handmaid Pieces for Harpsichord 8 Lesson A New Ground E minor.mid",
#   0.75),
#  ('Jerusalem Op208 D major.mid', 0.75),
#  ('The Tempest-Arise, ye subterranean winds D major.mid', 0.625),
#  ('Come ye sons of art away D major.mid', 0.5),
#  ('Sonata for Trumpet and String Orchestra 3 Allegro D major.mid', 0.5),
#  ('Gigue in D D major.mid', 0.5),
#  ('Oboe Sonata in G Movement 4 G major.mid', 0.375),
#  ('Hornpipe in E-ship-board version E minor.mid', 0.375),
#  ('Violin Concerto in D 3 Rondo Op6No1 D major.mid', 0.375),
#  ('Cinq Impromptus 3 Tres Modere G major.mid', 0.25),
#  ('The Yorkshire Feast Song 1 Symphony D major.mid', 0.25),
#  ('Sound the Trumpet, Come Ye Sons of Art G major.mid', 0.25),
#  ('Sonata for Trumpet and String Orchestra 1 Pomposo D major.mid', 0.25),
#  ('Praeludium in D for organ D minor.mid', 0),
#  ("Wir glauben all' an einen Gott D minor.mid", 0),
#  ('Minuet in G Op14No1 G major.mid', 0),
#  ('Prelude for Guitar and Harpsichord E major.mid', 0),
#  ('Chorale Preludes for Organ Wie schon leuchtet der Morgenstern T7 F major.mid',
#   0),
#  ('The Fairy Queen Act I Tune G minor Z629 G minor.mid', 0),
#  ('La Boheme Act 2 Al quartiere Latino Part 2 Ab major.mid', 0),
#  ('24 Caprices Presto Op1No16 G minor.mid', 0),
#  ('Ground in D D minor.mid', 0),
#  ('La Boheme Act 1 Questo mar rosso F# major.mid', 0),
#  ('Dance of the Hours E major.mid', 0),
#  ('24 Caprices Posato Op1No23 Eb major.mid', 0),
#  ('Preludes for Organ Prelude in A- T227 A minor.mid', 0),
#  ('March in C C major.mid', 0),
#  ('24 Caprices Sostenuto Op1No3 E minor.mid', 0),
#  ('The Fairy Queen Second Musick Rondeau-Maestoso Z629 Bb major.mid', 0),
#  ('La serva padrona Aria Son imbrogliato io gia Eb major.mid', 0),
#  ('Il Tabarro-Hai Ben Ragione C Minor.mid', 0),
#  ('Allegretto in E E major.mid', 0),
#  ('5 Transcriptions for Harpsichord 4 Volontary E minor.mid', 0),
#  ("Rossini's Barber of Seville Op36 C major.mid", 0),
#  ('Sonata for 2 violins bass and continuo in Eb 2 Canzona allegro No1 Eb major.mid',
#   0),
#  ('Sonata for violin and guitar- Allegro Op2No2 C major.mid', 0),
#  ('Minuet No1 A minor.mid', 0),
#  ('King Arthur Act III Frost Scene Opening and Recit C major.mid', 0),
#  ('Choral prelude for organ D major.mid', 0),
#  ('5 Transcriptions for Harpsichord 2 Agroud in gamut G major.mid', 0),
#  ('Preludes for Organ Prelude in Eb T223 Eb major.mid', 0),
#  ('The Tempest-Come Unto These Yellow Sands C major.mid', 0),
#  ('Stabat Mater 7 Eja mater fons amoris C minor.mid', 0),
#  ('Trio Sonata in D- for two recorders & continuo 2 Allegro D minor.mid', 0),
#  ('La serva padrona Aria A Serpina penserete Bb major.mid', 0),
#  ('La risurrezione di Cristo, oratorio in due parti Coro finale- Victimae paschali - alleluia F major.mid',
#   0),
#  ('Trois Mouvements Perpetuels 2 Tres modere D minor.mid', 0),
#  ('Cinq Impromptus 5 Andante C minor.mid', 0),
#  ('Piano Sonata in D 4 Vivace Op14No2 D minor.mid', 0),
#  ('Tosca III Orchestral Selection E major.mid', 0),
#  ('24 Caprices Presto Op1No24 A minor.mid', 0),
#  ('Magnificat fur vierstimmigen gemischten Chor und Basso continuo D major.mid',
#   0),
#  ('La Boheme 2 Mimi D major.mid', 0),
#  ('24 Caprices Maestoso Op1No8 Eb major.mid', 0),
#  ('24 Caprices Allegretto Op1No7 A minor.mid', 0),
#  ('Toccata in E- E minor.mid', 0),
#  ('La serva padrona Aria Stizzoso, mio stizzoso D major.mid', 0),
#  ('O Lamm Gottes unschuldig D major.mid', 0),
#  ('Gratulation D major.mid', 0),
#  ('Estrellita F# major.mid', 0),
#  ('Moto Perpetuo Op11 C major.mid', 0),
#  ('Jingle Bells F major.mid', 0),
#  ('Magnificat Septimi toni-Fugue No2 G minor.mid', 0),
#  ('Gianni Schicchi Ah che zucconi D major.mid', 0),
#  ('Ungarische Rhapsodie Op385 A minor.mid', 0),
#  ('Polonaise on a Theme from Rossinis Tancredi Op27 D major.mid', 0),
#  ('Chaconne Three Parts Upon a Ground F major.mid', 0),
#  ('King Arthur Fairest Isle F major.mid', 0),
#  ('La serva padrona Finale Contento tu sarai A major.mid', 0),
#  ('Flowers of Froso island Book 1 D minor.mid', 0),
#  ("Witches' Dance - Andante Eb major.mid", 0),
#  ('The Fairy Queen Act I Song in Two Parts- Let us Leave the Town Z629 C minor.mid',
#   0),
#  ('Madame Butterfly Act I Dovunque al mondo, in part Gb major.mid', 0),
#  ('Madame Butterfly Interlude between act 2 and 3 C major.mid', 0),
#  ('La serva padrona Aria Sempre in contrasti F major.mid', 0),
#  ('La Boheme Act 1 Che Gelida Manina F major.mid', 0),
#  ('Voluntary in C C major.mid', 0),
#  ('Capriccio breve G minor.mid', 0),
#  ('24 Caprices Allegretto Op1No20 D major.mid', 0),
#  ('La serva padrona Introd. Aspettare e non venire Bb major.mid', 0),
#  ('Magnificat Septimi toni-Fugue No1 G minor.mid', 0),
#  ('Tosca E lucevan le stelle B minor.mid', 0),
#  ('24 Caprices Sostenuto Op1No17 Eb major.mid', 0),
#  ("Chorale Preludes for Organ Nun lob, mein' Seel', den Herren T4 C major.mid",
#   0),
#  ('Military Rondo G major.mid', 0),
#  ('Trio Sonata in D- for two recorders & continuo 1 Adagio D minor.mid', 0),
#  ('Messa di Gloria 4 Sanctus G major.mid', 0),
#  ('Canzonetta Ab major.mid', 0),
#  ('Chorale Preludes for Organ Jesus Christus unser Heiland, der von uns T3 D minor.mid',
#   0),
#  ("Chorale Preludes for Organ Wir glauben all' an einen Gott T8 D minor.mid",
#   0),
#  ('La serva padrona Duetto La conosco a quegli occhietti G major.mid', 0),
#  ("Messa da Requiem a tre voci d'uomo 2 Graduale in memoria aeterna D minor.mid",
#   0),
#  ('24 Caprices Allegro Op1No13 Bb major.mid', 0),
#  ('Malibran Waltz Ab major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 1 Lesson Song Tune C major.mid",
#   0),
#  ('Last Variations A major.mid', 0),
#  ('Madame Butterfly Humming chorus Bb major.mid', 0),
#  ('Requiem D minor.mid', 0),
#  ('Missa Secunda Pontificalis Agnus Dei C# minor.mid', 0),
#  ('Hexachordum Apollinis - Aria e sei variationi D minor.mid', 0),
#  ('5 Transcriptions for Harpsichord 3 Prelude G major.mid', 0),
#  ("Chorale Preludes for Organ Vom Himmel hoch, da komm' ich her T6 D major.mid",
#   0),
#  ("Messa da Requiem a tre voci d'uomo 5 Offertorio Jesu Christe Rex Gloriae D minor.mid",
#   0),
#  ("5 Transcriptions for Harpsichord 5 Se fauchi's farewell C major.mid", 0),
#  ('Madame Butterfly Introduction C minor.mid', 0),
#  ("Chorale Preludes for Organ Ich ruf' zu dir, Herr Jesu Christ T2 E minor.mid",
#   0),
#  ('Missa Eucharistica a 4 voci, con organo Gloria Eb major.mid', 0),
#  ('Sonatina in C C major.mid', 0),
#  ('Lawn Tennis Bb major.mid', 0),
#  ('Sonata for 2 violins bass and continuo in Eb 3 Adagio No1 C minor.mid', 0),
#  ('24 Caprices Allegretto Op1No9 E major.mid', 0),
#  ('Missa Pontificalis Credo D minor.mid', 0),
#  ('Tarantella A minor.mid', 0),
#  ('Stabat Mater 2 Cujus animam gementem C minor.mid', 0),
#  ('Niobe (Cavatina - I tuoi frequenti palpiti) C major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 9 A New Irish Tune Lilliburlero G major.mid",
#   0),
#  ('Preludes for Organ Prelude in D- T221 D minor.mid', 0),
#  ('Sicilienne Eb major.mid', 0),
#  ('Dido And Aeneas 32 Our next motion Bb major.mid', 0),
#  ('Gianni Schicchi O mio babbino caro Ab major.mid', 0),
#  ('Messa di Gloria 2 Gloria C major.mid', 0),
#  ('24 Caprices Marestoso Op1No4 C minor.mid', 0),
#  ('Stabat Mater 1 Stabat Mater Dolorosa F minor.mid', 0),
#  ('No.12 Grande scena e aria di Carlo da Carlo di Borgogna C major.mid', 0),
#  ('Suite in G 3 Corant Z660 G major.mid', 0),
#  ('Stabat Mater 6 Vidit suum dulcem natum F minor.mid', 0),
#  ('Suite-Prelude No5 C major.mid', 0),
#  ('Missa Eucharistica a 4 voci, con organo Kyrie Eb major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 6 Lesson Minuet A minor.mid", 0),
#  ('Piano Sonata in A Op28No3 A minor.mid', 0),
#  ('Dido And Aeneas34 Witches Dance Bb major.mid', 0),
#  ('Trio Sonata in D- for two recorders & continuo 3 Largo D minor.mid', 0),
#  ('Intermezzo E minor.mid', 0),
#  ('If Music be the Food of Love D minor.mid', 0),
#  ('Ciacona (unf.) for organ in F F minor.mid', 0),
#  ('Dido And Aeneas 31 See the flags F major.mid', 0),
#  ('24 Caprices Vivace Op1No10 G minor.mid', 0),
#  ('Dido And Aeneas Act III-Come away, fellow sailors Bb major.mid', 0),
#  ('La Danse des Fees Eb major.mid', 0),
#  ('Air in G G major.mid', 0),
#  ('Madame Butterfly Addio Fiorito Asil Db major.mid', 0),
#  ('24 Caprices Allegro Op1No19 Eb major.mid', 0),
#  ('Suite No1 Minuet in G G major.mid', 0),
#  ('Oboe Sonata in G Movement 1 G major.mid', 0),
#  ('Sonata for 2 violins bass and continuo in Eb 4 Largo and Allegro No1 Eb major.mid',
#   0),
#  ('Sonate in C C major.mid', 0),
#  ('Ghiribizzi No14 C major.mid', 0),
#  ('Fantasy D minor.mid', 0),
#  ('Chi vuol la Zingarella F major.mid', 0),
#  ('Make Me Drunken With Deep Red Torrents Of Joy C major.mid', 0),
#  ('Piano Sonata in D 3 Andante Op14No2 G# major.mid', 0),
#  ('Sonata for Trumpet and String Orchestra 2 Andante Mastoso B minor.mid', 0),
#  ('Stabat Mater 4 Quae moerebat et dolebat C minor.mid', 0),
#  ('Trois Mouvements Perpetuels 3 Alerte F major.mid', 0),
#  ('Fuga for organ in E- E minor.mid', 0),
#  ('The Fairy Queen First Musick Hornpipe Z629 G minor.mid', 0),
#  ('Minuetto from Trio in D D major.mid', 0),
#  ('Missa Secunda Pontificalis Credo E major.mid', 0),
#  ('Toccata in A A major.mid', 0),
#  ('24 Caprices Moderato Op1No2 B minor.mid', 0),
#  ('Stabat Mater 5 Quis est homo C minor.mid', 0),
#  ('Minuet in A- A minor.mid', 0),
#  ('Preludes for Organ Prelude in E- T228 E minor.mid', 0),
#  ('Sonata for 2 violins, bass et BC in F Golden Sonata 4 Allegro No2 F major.mid',
#   0),
#  ('24 Caprices Andante Op1No1 G major.mid', 0),
#  ('Duet for one violin in C C major.mid', 0),
#  ('Stabat Mater 9 Sancta Mater, istud agas Eb major.mid', 0),
#  ('Hornpipe in E- E minor.mid', 0),
#  ('5 Transcriptions for Harpsichord 1 Hornpipe E minor.mid', 0),
#  ('24 Caprices Adagio Op1No6 G minor.mid', 0),
#  ('Sommarsang F major.mid', 0),
#  ('Trumpet Voluntary D major.mid', 0),
#  ('Dido And Aeneas Overture C minor.mid', 0),
#  ('Allegretto C major.mid', 0),
#  ("Chorale Preludes for Organ Dies sind die heil'gen zehn Gebot T1 C major.mid",
#   0),
#  ('Messa a tre voci maschili detta "Cerviana" Agnus Dei F major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 11 Lesson Sefauchi's Farewell D minor.mid",
#   0),
#  ('Canon in D D major.mid', 0),
#  ('Hornpipe in D D minor.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 4 Lesson New Minuet D minor.mid",
#   0),
#  ('Music for a While A minor.mid', 0),
#  ('Suite in G 2 Almand Z660 G major.mid', 0),
#  ('Sister Angelica Senza Mamma A minor.mid', 0),
#  ('Whistler and His Dog F major.mid', 0),
#  ('Magnificat Septimi toni-Fugue No4 A minor.mid', 0),
#  ('Dido And Aeneas Ah Belinda, I am prest with torment C minor.mid', 0),
#  ('La Boheme Act 2 Al quartiere Latino Part 1 F major.mid', 0),
#  ('La Serva Padrona - Aria di Serpina- Donne vaghe... Eb major.mid', 0),
#  ('Preludes and Fugue on a theme by J.S. Bach 1 Allegro con fuoco E minor.mid',
#   0),
#  ('The Fairy Queen Second Musick Air Z629  Bb major.mid', 0),
#  ('Theme with variations Op16No3 A major.mid', 0),
#  ('Fantaisie D minor.mid', 0),
#  ('Sonata for 2 violins, bass et BC in F Golden Sonata 2 Adagio No2 F minor.mid',
#   0),
#  ('La risurrezione di Cristo, oratorio in due parti Coro- recessit pastor noster C minor.mid',
#   0),
#  ('March Militaire F major.mid', 0),
#  ('King Arthur Two Dauters of the Aged Stream E minor.mid', 0),
#  ('24 Caprices Andante Op1No11 C major.mid', 0),
#  ('Trois Mouvements Perpetuels 1 Assez modere Bb major.mid', 0),
#  ('Preludes for Organ Prelude in G T224 G major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 2 Lesson Con Spirito C major.mid",
#   0),
#  ('Stabat Mater 12 Quando corpus morietur F minor.mid', 0),
#  ('Le Couvre-Feu A major.mid', 0),
#  ('Vom Himmel hoch da komm ich her - Choral-Vorspiel D major.mid', 0),
#  ('24 Caprices Moderato Op1No14 Eb major.mid', 0),
#  ("Messa da Requiem a tre voci d'uomo 7 Lux aeterna C major.mid", 0),
#  ('Hornpipe D minor.mid', 0),
#  ('La Danse des Fees F minor.mid', 0),
#  ('Chorale Preludes for Organ Vater unser im Himmelreich T5 D minor.mid', 0),
#  ('Les Naiades F major.mid', 0),
#  ('Messa a tre voci maschili detta "Cerviana" Kyrie D minor.mid', 0),
#  ('Piano Concerto in G 2 Scherzo Op16No2 D minor.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 5 Lesson Minuet A minor.mid", 0),
#  ('Ghiribizzi A major.mid', 0),
#  ('The Fairy Queen Overture Z629 D major.mid', 0),
#  ('Sonata for violin and guitar- Andante Op3No6 E minor.mid', 0),
#  ('Judith-Ballad "Long Since In Egypt\'s Plenteous Land", Act I Scene II Eb major.mid',
#   0),
#  ("Musick's Handmaid Pieces for Harpsichord 12 Lesson Minuet D minor.mid", 0),
#  ('Toccata Op11 D minor.mid', 0),
#  ('Tosca Vissi d arte Eb minor.mid', 0),
#  ('Piano Sonata in D 1 Allegro ma non troppo Op14No2 D minor.mid', 0),
#  ('The Fairy Queen Act I Chorus-Drive em hence Z629 F major.mid', 0),
#  ('Missa Pontificalis Gloria D minor.mid', 0),
#  ('Sonatina Op8No1 E major.mid', 0),
#  ('Vision Fugitives for piano Op22 A minor.mid', 0),
#  ("The Tempest-Stephano's Songs G major.mid", 0),
#  ('Corrente con variazioni A minor.mid', 0),
#  ('Judith-Introduction Bb major.mid', 0),
#  ("Messa da Requiem a tre voci d'uomo 8 Libera me Domine G minor.mid", 0),
#  ('Prelude G major.mid', 0),
#  ('24 Caprices Amoroso Op1No21 A major.mid', 0),
#  ('Stabat Mater 11 Inflammatus et accensus Bb major.mid', 0),
#  ('24 Caprices Allegro Op1No12 Ab major.mid', 0),
#  ('Messa di Gloria 1 Kyrie Ab major.mid', 0),
#  ('Missa Eucharistica a 4 voci, con organo Agnus Dei Eb major.mid', 0),
#  ('Allegretto Scherzando G major.mid', 0),
#  ('Magnificat Septimi toni-Fugue No7 F major.mid', 0),
#  ('King Arthur Genie of the Cold C minor.mid', 0),
#  ('Oboe Sonata in G Movement 3 G minor.mid', 0),
#  ('Stabat Mater 10 Fac ut portem Christi mortem G minor.mid', 0),
#  ('Cinq Impromptus 2 Allegro Vivace C major.mid', 0),
#  ('Trumpet Tune and Air D major.mid', 0),
#  ('Sonata for 2 violins, bass et BC in F Golden Sonata 3 Grave No2 F major.mid',
#   0),
#  ('Hornpipe in Bb Bb major.mid', 0),
#  ("Messa da Requiem a tre voci d'uomo 4 Dies irae D minor.mid", 0),
#  ('24 Caprices Marcato Op1No22 D minor.mid', 0),
#  ('Borry in D D major.mid', 0),
#  ('Sonata for 2 violins bass and continuo in Eb 1 Adagio No 1 Eb major.mid',
#   0),
#  ('Tosca Recondita Armonia F major.mid', 0),
#  ('Concerto for violin in B-La Campanella No2 B minor.mid', 0),
#  ('Missa Secunda Pontificalis Kyrie C# minor.mid', 0),
#  ('Messa a tre voci maschili detta "Cerviana" Gloria F major.mid', 0),
#  ('A New Irish Tune E major.mid', 0),
#  ('Suite in G 1 Prelude Z660 G major.mid', 0),
#  ('Messa a tre voci maschili detta "Cerviana" Credo F major.mid', 0),
#  ('The Fairy Queen First Musick Prelude Z629 Ab minor.mid', 0),
#  ('Trio Sonata in D- for two recorders & continuo 4 Allegro D minor.mid', 0),
#  ('Messa di Gloria 5 Agnus Dei C major.mid', 0),
#  ('Entry into the Summer-groove F major.mid', 0),
#  ("Messa da Requiem a tre voci d'uomo 1 Requiem-Kyrie F major.mid", 0),
#  ("Messa da Requiem a tre voci d'uomo 6 Sanctus-Benedictus G minor.mid", 0),
#  ('Madame Butterfly Un bel di Gb major.mid', 0),
#  ('Preludes for Organ Prelude in D- T222 D minor.mid', 0),
#  ('Fantasie le piano-forte in G G major.mid', 0),
#  ('The Tempest-Flout em and Scout em C major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 7 Lesson A New Scoth Tune G major.mid",
#   0),
#  ('Funeral Music of Queen Mary C major.mid', 0),
#  ('La risurrezione di Cristo, oratorio in due parti Storico- Cum autem sero factum esset G minor.mid',
#   0),
#  ('Missa Eucharistica a 4 voci, con organo Credo Eb major.mid', 0),
#  ("Dido And Aeneas Dido's Lement & When I am Laid in Earth C minor.mid", 0),
#  ('La Boheme 1 Che Gelida Manina Db major.mid', 0),
#  ('The Tempest-Full Fathom Five C major.mid', 0),
#  ('Magnificat Fuga F major.mid', 0),
#  ('I Was Glad When They Said Unto Me Bb major.mid', 0),
#  ('Messa a tre voci maschili detta "Cerviana" Sanctus-Benedictus D minor.mid',
#   0),
#  ('Sonata for 2 violins, bass et BC in F Golden Sonata 1 Allegro No2 F major.mid',
#   0),
#  ('Folie Db major.mid', 0),
#  ('Suite in G 4  Minuet Z660 G major.mid', 0),
#  ("Musick's Handmaid Pieces for Harpsichord 3 Lesson March C major.mid", 0),
#  ("Grand Sonata 'Romance' C minor.mid", 0),
#  ('La Campanella B minor.mid', 0),
#  ("Dido And Aeneas 33 Destruction's Bb major.mid", 0),
#  ('Grand Sonata in A 1 Allegro risoluto A major.mid', 0),
#  ('Stabat Mater 3 Oquam tristis et afflicta G minor.mid', 0),
#  ('Gianni Schicchi E fine C# minor.mid', 0),
#  ('Missa Pontificalis Agnus Dei D minor.mid', 0),
#  ('La serva padrona Duetto Per te ho io nel core D major.mid', 0),
#  ('Missa Pontificalis Sanctus D minor.mid', 0),
#  ('Presto C minor.mid', 0),
#  ('24 Caprices Corrente Op1No18 C major.mid', 0),
#  ('Preludes for Organ Prelude in G- T225 G minor.mid', 0),
#  ('Preludes for Organ Prelude in A T226 A major.mid', 0),
#  ('King Arthur Act III What Power Art Though and Thou Doating Fool C minor.mid',
#   0),
#  ('Nel cor piu non mi sento. For violin solo - Allegreto E minor.mid', 0),
#  ('Dioclesian Festival Rondeau - Maestoso D minor.mid', 0),
#  ('Abdalazer 2 Rondeau D minor.mid', 0),
#  ('The Fairy Queen Act I Scene of the Drunken Poet Z629 F major.mid', 0),
#  ('Cinq Impromptus 1 Tres Agite C major.mid', 0),
#  ('Magnificat in Bb Bb major.mid', 0),
#  ('Missa Secunda Pontificalis Sanctus-Benedictus C# minor.mid', 0),
#  ('Concerto for violin in Bb 1 Allegro Bb major.mid', 0),
#  ('Piano Sonata in D 2 Scherzo-Allegro Marcato Op14No2 A minor.mid', 0),
#  ('Missa Secunda Pontificalis Gloria C# minor.mid', 0),
#  ('Verse in the Phrygian mode Z126 A minor.mid', 0),
#  ('I Will Make An Everlasting Covenant Bb major.mid', 0),
#  ("Sonata per la Grand' Viola C minor.mid", 0),
#  ("Messa da Requiem a tre voci d'uomo 3 Tratto absolve domine Bb major.mid",
#   0),
#  ('Violin Concerto in D 2 Adagio Op6No1 B minor.mid', 0),
#  ('Cinq Impromptus 4 Violent C major.mid', 0.0),
#  ('La Boheme Selections Arr C major.mid', 0),
#  ('La Boheme Aria Quando men vo E major.mid', 0),
#  ('Manon Lescaut Donna non vida mai Bb major.mid', 0),
#  ('Capriccio e Variazioni C major.mid', 0.0),
#  ("Musick's Handmaid Pieces for Harpsichord 10 Lesson Rigadoon C major.mid",
#   0),
#  ('24 Caprices Agitato Op1No5 A minor.mid', 0),
#  ('Dioclesian What Shall I Do To Show How Much I Love Her A minor.mid', 0),
#  ('La risurrezione di Cristo, oratorio in due parti Duetto- Plange quasi virgo G major.mid',
#   0),
#  ('Oboe Sonata in G Movement 2 G major.mid', 0),
#  ('Sonata Concertata A major.mid', 0),
#  ('Missa Pontificalis Kyrie D minor.mid', 0),
#  ('Stabat Mater 8 Allegro Fac ut ardeat... -s, ct- G minor.mid', 0),
#  ('The Fairy Queen Act I Song Now Winter Comes Slowly Z629 A minor.mid', 0),
#  ('Toccata C major.mid', 0),
#  ('Ciacona in D- for organ D minor.mid', 0),
#  ('Nina, Canzonetta- G minor.mid', 0),
#  ('24 Caprices Posato Op1No15 E minor.mid', 0)]

# %%
data = pd.read_csv('YCAC-data-1/MozartSlices.csv', encoding= 'latin 1')
data[(data['file'] == 'Serenade No13 "Eine Kleine Nachtmusik" K525 ii C major.mid') &
    ]
# Out:
#          Unnamed: 0  Unnamed: 0.1   offset                           Chord  \
# 1019825     1019825       1019825    2.000                    ['E5', 'C4']
# 1019826     1019826       1019826    3.000                    ['E5', 'C4']
# 1019827     1019827       1019827    4.000        ['E5', 'C4', 'C3', 'C2']
# 1019828     1019828       1019828    4.500        ['E5', 'G3', 'C3', 'C2']
# 1019829     1019829       1019829    4.750                    ['E5', 'G3']
# ...             ...           ...      ...                             ...
# 1021255     1021255       1021255  388.375              ['D5', 'B4', 'F4']
# 1021256     1021256       1021256  389.000  ['D5', 'B4', 'F4', 'G2', 'G1']
# 1021257     1021257       1021257  389.375              ['D5', 'B4', 'F4']
# 1021258     1021258       1021258  390.000              ['C5', 'E4', 'C2']
# 1021259     1021259       1021259  390.375                    ['C5', 'E4']
#
#          HighestPitch  LowestPitch  \
# 1019825            76           60
# 1019826            76           60
# 1019827            76           36
# 1019828            76           36
# 1019829            76           55
# ...               ...          ...
# 1021255            74           65
# 1021256            74           31
# 1021257            74           65
# 1021258            72           36
# 1021259            72           64
#
#                                                       file Composer  \
# 1019825  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1019826  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1019827  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1019828  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1019829  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# ...                                                    ...      ...
# 1021255  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1021256  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1021257  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1021258  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
# 1021259  Serenade No13 "Eine Kleine Nachtmusik" K525 ii...   Mozart
#
#          Confidence
# 1019825    0.000000
# 1019826    0.000000
# 1019827    0.000000
# 1019828    0.841780
# 1019829    0.841780
# ...             ...
# 1021255    0.912734
# 1021256    0.912734
# 1021257    0.912734
# 1021258    0.912734
# 1021259    0.000000
#
# [1435 rows x 9 columns]

# %%
""" Mozart tests """
# has_notes(data['Chord'], ['F', 'E', 'D#', 'E', 'B', 'A', 'G#', 'A', 'B', 'A', 'G#', 'A', 'C'])
# has_notes(data['Chord'],['E', 'D#', 'E', 'B', 'A', 'G#', 'A', 'B', 'A', 'G#', 'A', 'C'])

""" Beethoven tests"""
has_notes(data['Chord'],['E', 'D#', 'E', 'D#', 'E', 'B', 'D', 'C', 'A'])
# Out:
# True

# %%
data = pd.read_csv('YCAC-data-1/BachSlices.csv')

# %%
file = open('YCAC-data-3/PSlicesByPiece', 'rb')
data = pickle.load(file)
data
# Out:
# {'Praeludium in D for organ D minor.mid':        Unnamed: 0  Unnamed: 0.1   offset                            Chord  \
#  53293       53293         53293    0.500                     ['D2', 'D3']
#  53294       53294         53294    1.000                     ['F2', 'F3']
#  53295       53295         53295    1.500                   ['C#2', 'C#3']
#  53296       53296         53296    2.000                     ['D2', 'D3']
#  53297       53297         53297    2.500                   ['A#2', 'A#3']
#  ...           ...           ...      ...                              ...
#  54808       54808         54808  377.375         ['D2', 'A3', 'D4', 'D3']
#  54809       54809         54809  377.500   ['D2', 'A3', 'D4', 'E3', 'D3']
#  54810       54810         54810  377.875         ['D2', 'A3', 'D4', 'D3']
#  54811       54811         54811  378.000  ['D2', 'A3', 'D4', 'F#3', 'D3']
#  54812       54812         54812  379.250                          ['F#3']
#
#         HighestPitch  LowestPitch                                   file  \
#  53293            50           38  Praeludium in D for organ D minor.mid
#  53294            53           41  Praeludium in D for organ D minor.mid
#  53295            49           37  Praeludium in D for organ D minor.mid
#  53296            50           38  Praeludium in D for organ D minor.mid
#  53297            58           46  Praeludium in D for organ D minor.mid
#  ...             ...          ...                                    ...
#  54808            62           38  Praeludium in D for organ D minor.mid
#  54809            62           38  Praeludium in D for organ D minor.mid
#  54810            62           38  Praeludium in D for organ D minor.mid
#  54811            62           38  Praeludium in D for organ D minor.mid
#  54812            54           54  Praeludium in D for organ D minor.mid
#
#          Composer  Confidence
#  53293  Pachelbel    0.000000
#  53294  Pachelbel    0.000000
#  53295  Pachelbel    0.000000
#  53296  Pachelbel    0.000000
#  53297  Pachelbel    0.000000
#  ...          ...         ...
#  54808  Pachelbel    0.913883
#  54809  Pachelbel    0.913883
#  54810  Pachelbel    0.000000
#  54811  Pachelbel    0.000000
#  54812  Pachelbel    0.000000
#
#  [1520 rows x 9 columns],
#  "Wir glauben all' an einen Gott D minor.mid":         Unnamed: 0  Unnamed: 0.1  offset                Chord  HighestPitch  \
#  187913      187913        187913    4.00         ['D3', 'F3']            53
#  187914      187914        187914    4.25   ['D4', 'D3', 'F3']            62
#  187915      187915        187915    4.50  ['C#4', 'D3', 'F3']            61
#  187916      187916        187916    4.75   ['D4', 'D3', 'F3']            62
#  187917      187917        187917    5.00   ['A3', 'D3', 'F3']            57
#  ...            ...           ...     ...                  ...           ...
#  188851      188851        188851  276.00  ['D4', 'D3', 'F#3']            62
#  188852      188852        188852  276.50  ['D4', 'G3', 'A#3']            62
#  188853      188853        188853  277.00  ['D4', 'F#3', 'A3']            62
#  188854      188854        188854  277.50   ['D4', 'E3', 'G3']            62
#  188855      188855        188855  278.00  ['D4', 'D3', 'F#3']            62
#
#          LowestPitch                                        file   Composer  \
#  187913           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  187914           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  187915           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  187916           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  187917           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  ...             ...                                         ...        ...
#  188851           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  188852           55  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  188853           54  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  188854           52  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#  188855           50  Wir glauben all' an einen Gott D minor.mid  Pachelbel
#
#          Confidence
#  187913         0.0
#  187914         0.0
#  187915         0.0
#  187916         0.0
#  187917         0.0
#  ...            ...
#  188851         0.0
#  188852         0.0
#  188853         0.0
#  188854         0.0
#  188855         0.0
#
#  [943 rows x 9 columns],
#  'Minuet in G Op14No1 G major.mid':         Unnamed: 0  Unnamed: 0.1   offset  \
#  188856      188856        188856   12.250
#  188857      188857        188857   13.375
#  188858      188858        188858   14.500
#  188859      188859        188859   15.625
#  188860      188860        188860   15.750
#  ...            ...           ...      ...
#  190514      190514        190514  568.250
#  190515      190515        190515  568.375
#  190516      190516        190516  570.375
#  190517      190517        190517  570.500
#  190518      190518        190518  570.625
#
#                                                      Chord  HighestPitch  \
#  188856                                             ['D4']            62
#  188857                                 ['D5', 'B3', 'D4']            74
#  188858                                 ['D5', 'B3', 'D4']            74
#  188859                                 ['C5', 'A3', 'D4']            72
#  188860                           ['D5', 'C5', 'A3', 'D4']            74
#  ...                                                   ...           ...
#  190514                                 ['B5', 'B4', 'D5']            83
#  190515                                             ['B5']            83
#  190516                                             ['G1']            31
#  190517  ['G5', 'D4', 'G4', 'B4', 'D5', 'G3', 'B3', 'D3...            79
#  190518   ['G5', 'D4', 'G4', 'B4', 'D5', 'G3', 'B3', 'D3']            79
#
#          LowestPitch                             file    Composer  Confidence
#  188856           62  Minuet in G Op14No1 G major.mid  Paderewski    0.782622
#  188857           59  Minuet in G Op14No1 G major.mid  Paderewski    0.788415
#  188858           59  Minuet in G Op14No1 G major.mid  Paderewski    0.826447
#  188859           57  Minuet in G Op14No1 G major.mid  Paderewski    0.831361
#  188860           57  Minuet in G Op14No1 G major.mid  Paderewski    0.831361
#  ...             ...                              ...         ...         ...
#  190514           71  Minuet in G Op14No1 G major.mid  Paderewski    0.753245
#  190515           83  Minuet in G Op14No1 G major.mid  Paderewski    0.658543
#  190516           31  Minuet in G Op14No1 G major.mid  Paderewski    0.000000
#  190517           31  Minuet in G Op14No1 G major.mid  Paderewski    0.000000
#  190518           50  Minuet in G Op14No1 G major.mid  Paderewski    0.000000
#
#  [1663 rows x 9 columns],
#  'Prelude for Guitar and Harpsichord E major.mid':         Unnamed: 0  Unnamed: 0.1   offset                            Chord  \
#  290200      290200        290200    0.000                           ['E2']
#  290201      290201        290201    0.500              ['B4', 'F#3', 'E2']
#  290202      290202        290202    0.625                     ['B4', 'E2']
#  290203      290203        290203    1.000              ['B4', 'G#3', 'E2']
#  290204      290204        290204    1.125                     ['B4', 'E2']
#  ...            ...           ...      ...                              ...
#  291311      291311        291311  270.000              ['G#3', 'B5', 'E2']
#  291312      291312        291312  270.125  ['B3', 'E4', 'G#3', 'B5', 'E2']
#  291313      291313        291313  270.250  ['E4', 'G#3', 'B3', 'E2', 'B5']
#  291314      291314        291314  270.500        ['G#3', 'B3', 'E4', 'E2']
#  291315      291315        291315  270.875              ['G#3', 'B3', 'E4']
#
#          HighestPitch  LowestPitch  \
#  290200            40           40
#  290201            71           40
#  290202            71           40
#  290203            71           40
#  290204            71           40
#  ...              ...          ...
#  291311            83           40
#  291312            83           40
#  291313            83           40
#  291314            64           40
#  291315            64           56
#
#                                                    file Composer  Confidence
#  290200  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  290201  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  290202  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  290203  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  290204  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  ...                                                ...      ...         ...
#  291311  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  291312  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  291313  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  291314  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#  291315  Prelude for Guitar and Harpsichord E major.mid    Ponce         0.0
#
#  [1116 rows x 9 columns],
#  'Come ye sons of art away D major.mid':        Unnamed: 0  Unnamed: 0.1    offset  \
#  63308       63308         63308     0.000
#  63309       63309         63309     0.875
#  63310       63310         63310     1.000
#  63311       63311         63311     1.875
#  63312       63312         63312     2.000
#  ...           ...           ...       ...
#  70763       70763         70763  2462.750
#  70764       70764         70764  2462.875
#  70765       70765         70765  2463.000
#  70766       70766         70766  2463.750
#  70767       70767         70767  2465.750
#
#                                                     Chord  HighestPitch  \
#  63308                          ['D4', 'F#4', 'A4', 'D3']            69
#  63309                          ['D4', 'F#4', 'A4', 'D3']            69
#  63310                          ['E4', 'G4', 'A4', 'C#3']            69
#  63311                          ['E4', 'G4', 'A4', 'C#3']            69
#  63312                          ['D4', 'F#4', 'A4', 'D3']            69
#  ...                                                  ...           ...
#  70763              ['B5', 'A2', 'D5', 'A4', 'C#5', 'D3']            83
#  70764                           ['B5', 'A4', 'D5', 'D3']            83
#  70765  ['B4', 'F#5', 'B5', 'D3', 'D4', 'F#4', 'A4', '...            83
#  70766  ['B4', 'D5', 'F#5', 'B5', 'D3', 'D4', 'F#4', '...            83
#  70767                    ['B4', 'D5', 'F#5', 'B5', 'A2']            83
#
#         LowestPitch                                  file Composer  Confidence
#  63308           50  Come ye sons of art away D major.mid  Purcell    0.000000
#  63309           50  Come ye sons of art away D major.mid  Purcell    0.869588
#  63310           49  Come ye sons of art away D major.mid  Purcell    0.869588
#  63311           49  Come ye sons of art away D major.mid  Purcell    0.869588
#  63312           50  Come ye sons of art away D major.mid  Purcell    0.869588
#  ...            ...                                   ...      ...         ...
#  70763           45  Come ye sons of art away D major.mid  Purcell    0.906835
#  70764           50  Come ye sons of art away D major.mid  Purcell    0.906835
#  70765           38  Come ye sons of art away D major.mid  Purcell    0.906835
#  70766           38  Come ye sons of art away D major.mid  Purcell    0.876533
#  70767           45  Come ye sons of art away D major.mid  Purcell    0.000000
#
#  [7460 rows x 9 columns],
#  'Chorale Preludes for Organ Wie schon leuchtet der Morgenstern T7 F major.mid':         Unnamed: 0  Unnamed: 0.1      offset  \
#  294836      294836        294836    1.000000
#  294837      294837        294837    2.000000
#  294838      294838        294838    3.000000
#  294839      294839        294839    4.000000
#  294840      294840        294840    5.000000
#  ...            ...           ...         ...
#  295840      295840        295840  222.500000
#  295841      295841        295841  222.625000
#  295842      295842        295842  222.666667
#  295843      295843        295843  222.875000
#  295844      295844        295844  224.250000
#
#                                         Chord  HighestPitch  LowestPitch  \
#  294836                                ['F4']            65           65
#  294837                                ['C5']            72           72
#  294838                                ['A4']            69           69
#  294839                                ['F4']            65           65
#  294840                                ['C5']            72           72
#  ...                                      ...           ...          ...
#  295840  ['A3', 'C4', 'E4', 'F4', 'F1', 'F2']            65           29
#  295841  ['A3', 'C4', 'E4', 'F4', 'F1', 'F2']            65           29
#  295842  ['A3', 'C4', 'F4', 'E4', 'F1', 'F2']            65           29
#  295843        ['A3', 'C4', 'F4', 'F1', 'F2']            65           29
#  295844                                ['F4']            65           65
#
#                                                       file   Composer  \
#  294836  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  294837  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  294838  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  294839  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  294840  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  ...                                                   ...        ...
#  295840  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  295841  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  295842  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  295843  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#  295844  Chorale Preludes for Organ Wie schon leuchtet ...  Pachelbel
#
#          Confidence
#  294836    0.700496
#  294837    0.700496
#  294838    0.700496
#  294839    0.700496
#  294840    0.700496
#  ...            ...
#  295840    0.000000
#  295841    0.000000
#  295842    0.000000
#  295843    0.000000
#  295844    0.000000
#
#  [1009 rows x 9 columns],
#  'The Fairy Queen Act I Tune G minor Z629 G minor.mid':         Unnamed: 0  Unnamed: 0.1   offset                      Chord  \
#  241672      241672        241672    0.000               ['D5', 'A4']
#  241673      241673        241673    1.000              ['G5', 'A#4']
#  241674      241674        241674    2.500               ['A5', 'C5']
#  241675      241675        241675    3.000        ['G5', 'A#4', 'G3']
#  241676      241676        241676    4.000         ['F5', 'A4', 'D4']
#  ...            ...           ...      ...                        ...
#  242083      242083        242083  233.625              ['A4', 'F#4']
#  242084      242084        242084  233.875                    ['F#4']
#  242085      242085        242085  234.000  ['G4', 'F#4', 'D4', 'D2']
#  242086      242086        242086  234.625         ['G4', 'D4', 'D2']
#  242087      242087        242087  235.000         ['G4', 'D4', 'G2']
#
#          HighestPitch  LowestPitch  \
#  241672            74           69
#  241673            79           70
#  241674            81           72
#  241675            79           55
#  241676            77           62
#  ...              ...          ...
#  242083            69           66
#  242084            66           66
#  242085            67           38
#  242086            67           38
#  242087            67           43
#
#                                                       file Composer  Confidence
#  241672  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.854042
#  241673  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.854042
#  241674  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.854042
#  241675  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.854042
#  241676  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.854042
#  ...                                                   ...      ...         ...
#  242083  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.947632
#  242084  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.947632
#  242085  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.947632
#  242086  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.895823
#  242087  The Fairy Queen Act I Tune G minor Z629 G mino...  Purcell    0.895823
#
#  [416 rows x 9 columns],
#  'La Boheme Act 2 Al quartiere Latino Part 2 Ab major.mid':         Unnamed: 0  Unnamed: 0.1    offset  \
#  247344      247344        247344     4.625
#  247345      247345        247345     5.125
#  247346      247346        247346     5.625
#  247347      247347        247347     6.000
#  247348      247348        247348     6.375
#  ...            ...           ...       ...
#  251662      251662        251662  1043.875
#  251663      251663        251663  1044.125
#  251664      251664        251664  1044.375
#  251665      251665        251665  1045.625
#  251666      251666        251666  1046.750
#
#                                             Chord  HighestPitch  LowestPitch  \
#  247344                                    ['E4']            64           64
#  247345                                    ['E4']            64           64
#  247346                                    ['E4']            64           64
#  247347                                    ['E4']            64           64
#  247348                                   ['D#4']            63           63
#  ...                                          ...           ...          ...
#  251662                        ['D3', 'D2', 'G5']            79           38
#  251663                      ['D#3', 'D#2', 'D6']            86           39
#  251664                        ['C6', 'F2', 'F3']            84           41
#  251665      ['F5', 'A5', 'F3', 'C6', 'F6', 'F2']            89           41
#  251666  ['A#6', 'A#5', 'F6', 'D6', 'A#1', 'A#2']            94           34
#
#                                                       file Composer  Confidence
#  247344  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.759350
#  247345  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.876937
#  247346  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.876937
#  247347  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.886848
#  247348  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.886848
#  ...                                                   ...      ...         ...
#  251662  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.937770
#  251663  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.937770
#  251664  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.937770
#  251665  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.000000
#  251666  La Boheme Act 2 Al quartiere Latino Part 2 Ab ...  Puccini    0.000000
#
#  [4323 rows x 9 columns],
#  '24 Caprices Presto Op1No16 G minor.mid':         Unnamed: 0  Unnamed: 0.1  offset               Chord  HighestPitch  \
#  109837      109837        109837    3.00              ['G4']            67
#  109838      109838        109838    3.25             ['A#4']            70
#  109839      109839        109839    3.50              ['D5']            74
#  109840      109840        109840    3.75              ['G5']            79
#  109841      109841        109841    4.00              ['A5']            81
#  ...            ...           ...     ...                 ...           ...
#  110544      110544        110544  182.00              ['C4']            60
#  110545      110545        110545  182.25             ['C#4']            61
#  110546      110546        110546  182.50              ['D4']            62
#  110547      110547        110547  182.75             ['A#3']            58
#  110548      110548        110548  183.00  ['G5', 'G3', 'D4']            79
#
#          LowestPitch                                    file  Composer  \
#  109837           67  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  109838           70  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  109839           74  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  109840           79  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  109841           81  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  ...             ...                                     ...       ...
#  110544           60  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  110545           61  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  110546           62  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  110547           58  24 Caprices Presto Op1No16 G minor.mid  Paganini
#  110548           55  24 Caprices Presto Op1No16 G minor.mid  Paganini
#
#          Confidence
#  109837    0.793883
#  109838    0.793883
#  109839    0.793883
#  109840    0.793883
#  109841    0.793883
#  ...            ...
#  110544    0.718527
#  110545    0.718527
#  110546    0.718527
#  110547    0.718527
#  110548    0.718527
#
#  [712 rows x 9 columns],
#  'Ground in D D minor.mid':        Unnamed: 0  Unnamed: 0.1   offset               Chord  HighestPitch  \
#  35232       35232         35232    4.000        ['D5', 'D3']            74
#  35233       35233         35233    4.500        ['D4', 'D5']            74
#  35234       35234         35234    4.875       ['C#4', 'D5']            74
#  35235       35235         35235    5.000              ['D5']            74
#  35236       35236         35236    5.375        ['D4', 'D5']            74
#  ...           ...           ...      ...                 ...           ...
#  35867       35867         35867  149.000        ['D5', 'A2']            74
#  35868       35868         35868  149.375              ['A2']            45
#  35869       35869         35869  149.625  ['D5', 'D3', 'A2']            74
#  35870       35870         35870  149.875        ['D5', 'D3']            74
#  35871       35871         35871  153.750  ['D2', 'D5', 'D3']            74
#
#         LowestPitch                     file Composer  Confidence
#  35232           50  Ground in D D minor.mid  Purcell    0.712442
#  35233           62  Ground in D D minor.mid  Purcell    0.809846
#  35234           61  Ground in D D minor.mid  Purcell    0.809846
#  35235           74  Ground in D D minor.mid  Purcell    0.809846
#  35236           62  Ground in D D minor.mid  Purcell    0.896675
#  ...            ...                      ...      ...         ...
#  35867           45  Ground in D D minor.mid  Purcell    0.826731
#  35868           45  Ground in D D minor.mid  Purcell    0.698455
#  35869           45  Ground in D D minor.mid  Purcell    0.698455
#  35870           50  Ground in D D minor.mid  Purcell    0.698455
#  35871           38  Ground in D D minor.mid  Purcell    0.000000
#
#  [640 rows x 9 columns],
#  'La Boheme Act 1 Questo mar rosso F# major.mid':         Unnamed: 0  Unnamed: 0.1    offset                     Chord  \
#  259241      259241        259241     2.750              ['G1', 'G2']
#  259242      259242        259242     2.875              ['G2', 'G1']
#  259243      259243        259243     3.250            ['F#1', 'F#2']
#  259244      259244        259244     3.625              ['F1', 'F2']
#  259245      259245        259245     3.750  ['G3', 'B2', 'F1', 'F2']
#  ...            ...           ...       ...                       ...
#  264504      264504        264504  1296.125                   ['F#4']
#  264505      264505        264505  1296.625                   ['A#4']
#  264506      264506        264506  1296.875                   ['C#4']
#  264507      264507        264507  1298.375            ['C#2', 'C#3']
#  264508      264508        264508  1299.875            ['F#1', 'F#2']
#
#          HighestPitch  LowestPitch  \
#  259241            43           31
#  259242            43           31
#  259243            42           30
#  259244            41           29
#  259245            55           29
#  ...              ...          ...
#  264504            66           66
#  264505            70           70
#  264506            61           61
#  264507            49           37
#  264508            42           30
#
#                                                   file Composer  Confidence
#  259241  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.620516
#  259242  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.620516
#  259243  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.620516
#  259244  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.620516
#  259245  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.620516
#  ...                                               ...      ...         ...
#  264504  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.862523
#  264505  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.862523
#  264506  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.862523
#  264507  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.815193
#  264508  La Boheme Act 1 Questo mar rosso F# major.mid  Puccini    0.000000
#
#  [5268 rows x 9 columns],
#  'Dance of the Hours E major.mid':        Unnamed: 0  Unnamed: 0.1   offset  \
#  19287       19287         19287    3.000
#  19288       19288         19288    3.250
#  19289       19289         19289    4.000
#  19290       19290         19290    4.250
#  19291       19291         19291    5.000
#  ...           ...           ...      ...
#  22358       22358         22358  873.500
#  22359       22359         22359  873.625
#  22360       22360         22360  873.750
#  22361       22361         22361  873.875
#  22362       22362         22362  874.000
#
#                                                     Chord  HighestPitch  \
#  19287                                            ['G#4']            68
#  19288                                             ['B4']            71
#  19289                                       ['E2', 'B4']            71
#  19290                                            ['C#5']            73
#  19291                                            ['G#3']            56
#  ...                                                  ...           ...
#  22358  ['A6', 'C#4', 'E4', 'A3', 'A1', 'E5', 'A5', 'A...            93
#  22359  ['A6', 'C#4', 'E4', 'A3', 'A1', 'E5', 'A5', 'A...            93
#  22360  ['A6', 'C#5', 'A3', 'C#4', 'E4', 'A1', 'E5', '...            93
#  22361  ['A6', 'A3', 'A4', 'C#4', 'E4', 'A2', 'A1', 'E...            93
#  22362                           ['A3', 'A4', 'A2', 'E5']            76
#
#         LowestPitch                            file    Composer  Confidence
#  19287           68  Dance of the Hours E major.mid  Ponchielli    0.951448
#  19288           71  Dance of the Hours E major.mid  Ponchielli    0.951448
#  19289           40  Dance of the Hours E major.mid  Ponchielli    0.951448
#  19290           73  Dance of the Hours E major.mid  Ponchielli    0.951448
#  19291           56  Dance of the Hours E major.mid  Ponchielli    0.951448
#  ...            ...                             ...         ...         ...
#  22358           33  Dance of the Hours E major.mid  Ponchielli    0.756713
#  22359           33  Dance of the Hours E major.mid  Ponchielli    0.756713
#  22360           33  Dance of the Hours E major.mid  Ponchielli    0.756713
#  22361           33  Dance of the Hours E major.mid  Ponchielli    0.756713
#  22362           45  Dance of the Hours E major.mid  Ponchielli    0.756713
#
#  [3076 rows x 9 columns],
#  '24 Caprices Posato Op1No23 Eb major.mid':         Unnamed: 0  Unnamed: 0.1   offset               Chord  HighestPitch  \
#  140836      140836        140836    0.000      ['A#5', 'A#4']            82
#  140837      140837        140837    0.500      ['D#5', 'D#6']            87
#  140838      140838        140838    1.500             ['A#3']            58
#  140839      140839        140839    1.750              ['C4']            60
#  140840      140840        140840    1.875              ['D4']            62
#  ...            ...           ...      ...                 ...           ...
#  141376      141376        141376  112.000              ['F4']            65
#  141377      141377        141377  112.125             ['G#6']            92
#  141378      141378        141378  112.750        ['D4', 'G3']            62
#  141379      141379        141379  113.000        ['B4', 'G5']            79
#  141380      141380        141380  113.750  ['C5', 'G3', 'C4']            72
#
#          LowestPitch                                     file  Composer  \
#  140836           70  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  140837           75  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  140838           58  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  140839           60  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  140840           62  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  ...             ...                                      ...       ...
#  141376           65  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  141377           92  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  141378           55  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  141379           71  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#  141380           55  24 Caprices Posato Op1No23 Eb major.mid  Paganini
#
#          Confidence
#  140836    0.000000
#  140837    0.000000
#  140838    0.000000
#  140839    0.000000
#  140840    0.000000
#  ...            ...
#  141376    0.854379
#  141377    0.854379
#  141378    0.854379
#  141379    0.854379
#  141380    0.000000
#
#  [545 rows x 9 columns],
#  'Preludes for Organ Prelude in A- T227 A minor.mid':         Unnamed: 0  Unnamed: 0.1  offset                            Chord  \
#  243170      243170        243170   0.000                     ['A2', 'A3']
#  243171      243171        243171   1.000         ['C5', 'A4', 'A2', 'A3']
#  243172      243172        243172   2.000         ['D5', 'B4', 'A2', 'A3']
#  243173      243173        243173   3.000       ['E5', 'B4', 'G#2', 'G#3']
#  243174      243174        243174   4.000         ['E5', 'B4', 'C3', 'C4']
#  243175      243175        243175   4.500         ['C5', 'E5', 'C3', 'C4']
#  243176      243176        243176   5.000         ['A4', 'E5', 'C3', 'C4']
#  243177      243177        243177   5.500         ['F5', 'A4', 'C3', 'C4']
#  243178      243178        243178   6.000         ['D5', 'A4', 'B2', 'B3']
#  243179      243179        243179   6.500         ['B4', 'D5', 'B2', 'B3']
#  243180      243180        243180   7.000        ['G#4', 'D5', 'E2', 'E3']
#  243181      243181        243181   7.500        ['C5', 'G#4', 'E2', 'E3']
#  243182      243182        243182   7.750        ['B4', 'G#4', 'E2', 'E3']
#  243183      243183        243183   8.000         ['C5', 'A4', 'A2', 'A3']
#  243184      243184        243184   8.500         ['E4', 'C5', 'A2', 'A3']
#  243185      243185        243185   9.000         ['F4', 'C5', 'A2', 'A3']
#  243186      243186        243186  10.000         ['B4', 'F4', 'G2', 'G3']
#  243187      243187        243187  11.000         ['C5', 'E4', 'C3', 'C4']
#  243188      243188        243188  12.000         ['D5', 'F4', 'C3', 'C4']
#  243189      243189        243189  13.000         ['G4', 'D5', 'B2', 'B3']
#  243190      243190        243190  13.500         ['F4', 'D5', 'B2', 'B3']
#  243191      243191        243191  14.000         ['E4', 'D5', 'C3', 'C4']
#  243192      243192        243192  15.000         ['C5', 'E4', 'A2', 'A3']
#  243193      243193        243193  15.500         ['E4', 'C5', 'A2', 'A3']
#  243194      243194        243194  16.000       ['D4', 'C5', 'F#2', 'F#3']
#  243195      243195        243195  16.500       ['C5', 'D4', 'F#2', 'F#3']
#  243196      243196        243196  17.000       ['B4', 'D4', 'G#2', 'G#3']
#  243197      243197        243197  17.500       ['D4', 'B4', 'G#2', 'G#3']
#  243198      243198        243198  18.000         ['C4', 'B4', 'A2', 'A3']
#  243199      243199        243199  18.500         ['B4', 'C4', 'A2', 'A3']
#  243200      243200        243200  19.000         ['A4', 'C4', 'C2', 'C3']
#  243201      243201        243201  19.500         ['C4', 'A4', 'C2', 'C3']
#  243202      243202        243202  20.000         ['B3', 'A4', 'D2', 'D3']
#  243203      243203        243203  20.500         ['A4', 'B3', 'D2', 'D3']
#  243204      243204        243204  21.000         ['G4', 'B3', 'E2', 'E3']
#  243205      243205        243205  21.500         ['B3', 'G4', 'E2', 'E3']
#  243206      243206        243206  22.000         ['A3', 'G4', 'F2', 'F3']
#  243207      243207        243207  22.500         ['G4', 'A3', 'F2', 'F3']
#  243208      243208        243208  23.000         ['F4', 'A3', 'A1', 'A2']
#  243209      243209        243209  23.500         ['A3', 'F4', 'A1', 'A2']
#  243210      243210        243210  24.000         ['G3', 'F4', 'B1', 'B2']
#  243211      243211        243211  24.500         ['F4', 'G3', 'B1', 'B2']
#  243212      243212        243212  25.000               ['E4', 'C2', 'C3']
#  243213      243213        243213  25.500         ['G4', 'E4', 'C2', 'C3']
#  243214      243214        243214  26.000         ['A4', 'E4', 'F2', 'F3']
#  243215      243215        243215  26.500         ['E4', 'A4', 'F2', 'F3']
#  243216      243216        243216  27.000         ['D4', 'A4', 'F2', 'F3']
#  243217      243217        243217  27.500         ['B4', 'D4', 'F2', 'F3']
#  243218      243218        243218  28.000        ['G#4', 'D4', 'E2', 'E3']
#  243219      243219        243219  29.000         ['C4', 'A4', 'E2', 'E3']
#  243220      243220        243220  30.000         ['B3', 'A4', 'E2', 'E3']
#  243221      243221        243221  31.000        ['G#4', 'B3', 'E1', 'E2']
#  243222      243222        243222  31.500       ['C#4', 'G#4', 'E1', 'E2']
#  243223      243223        243223  31.750        ['D4', 'G#4', 'E1', 'E2']
#  243224      243224        243224  32.000  ['C#4', 'E4', 'A4', 'A1', 'A2']
#  243225      243225        243225  35.875                           ['A4']
#
#          HighestPitch  LowestPitch  \
#  243170            57           45
#  243171            72           45
#  243172            74           45
#  243173            76           44
#  243174            76           48
#  243175            76           48
#  243176            76           48
#  243177            77           48
#  243178            74           47
#  243179            74           47
#  243180            74           40
#  243181            72           40
#  243182            71           40
#  243183            72           45
#  243184            72           45
#  243185            72           45
#  243186            71           43
#  243187            72           48
#  243188            74           48
#  243189            74           47
#  243190            74           47
#  243191            74           48
#  243192            72           45
#  243193            72           45
#  243194            72           42
#  243195            72           42
#  243196            71           44
#  243197            71           44
#  243198            71           45
#  243199            71           45
#  243200            69           36
#  243201            69           36
#  243202            69           38
#  243203            69           38
#  243204            67           40
#  243205            67           40
#  243206            67           41
#  243207            67           41
#  243208            65           33
#  243209            65           33
#  243210            65           35
#  243211            65           35
#  243212            64           36
#  243213            67           36
#  243214            69           41
#  243215            69           41
#  243216            69           41
#  243217            71           41
#  243218            68           40
#  243219            69           40
#  243220            69           40
#  243221            68           28
#  243222            68           28
#  243223            68           28
#  243224            69           33
#  243225            69           69
#
#                                                       file   Composer  \
#  243170  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243171  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243172  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243173  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243174  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243175  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243176  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243177  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243178  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243179  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243180  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243181  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243182  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243183  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243184  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243185  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243186  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243187  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243188  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243189  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243190  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243191  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243192  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243193  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243194  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243195  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243196  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243197  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243198  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243199  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243200  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243201  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243202  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243203  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243204  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243205  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243206  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243207  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243208  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243209  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243210  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243211  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243212  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243213  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243214  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243215  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243216  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243217  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243218  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243219  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243220  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243221  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243222  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243223  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243224  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#  243225  Preludes for Organ Prelude in A- T227 A minor.mid  Pachelbel
#
#          Confidence
#  243170    0.932736
#  243171    0.932736
#  243172    0.932736
#  243173    0.932736
#  243174    0.932736
#  243175    0.932736
#  243176    0.932736
#  243177    0.932736
#  243178    0.932736
#  243179    0.932736
#  243180    0.932736
#  243181    0.932736
#  243182    0.932736
#  243183    0.932736
#  243184    0.927346
#  243185    0.927346
#  243186    0.917143
#  243187    0.896208
#  243188    0.754482
#  243189    0.754482
#  243190    0.754482
#  243191    0.754482
#  243192    0.754482
#  243193    0.754482
#  243194    0.754482
#  243195    0.754482
#  243196    0.754482
#  243197    0.000000
#  243198    0.000000
#  243199    0.000000
#  243200    0.000000
#  243201    0.000000
#  243202    0.000000
#  243203    0.000000
#  243204    0.000000
#  243205    0.748438
#  243206    0.748438
#  243207    0.869147
#  243208    0.869147
#  243209    0.869147
#  243210    0.869147
#  243211    0.869147
#  243212    0.869147
#  243213    0.869147
#  243214    0.869147
#  243215    0.881867
#  243216    0.881867
#  243217    0.881867
#  243218    0.881867
#  243219    0.881867
#  243220    0.881867
#  243221    0.881867
#  243222    0.881867
#  243223    0.881867
#  243224    0.881867
#  243225    0.000000  ,
#  'March in C C major.mid':         Unnamed: 0  Unnamed: 0.1  offset                           Chord  \
#  289438      289438        289438     3.5                          ['C5']
#  289439      289439        289439     4.0        ['C5', 'G4', 'E4', 'C4']
#  289440      289440        289440     5.0        ['B3', 'C5', 'G4', 'E4']
#  289441      289441        289441     5.5        ['A3', 'C5', 'G4', 'E4']
#  289442      289442        289442     6.0        ['G3', 'C5', 'G4', 'E4']
#  ...            ...           ...     ...                             ...
#  289743      289743        289743   191.0                    ['C5', 'E2']
#  289744      289744        289744   191.5                    ['C5', 'D2']
#  289745      289745        289745   192.0        ['G4', 'E4', 'C5', 'C2']
#  289746      289746        289746   193.0  ['G2', 'G4', 'E4', 'C5', 'C2']
#  289747      289747        289747   194.0  ['C3', 'G4', 'E4', 'C5', 'C2']
#
#          HighestPitch  LowestPitch                    file Composer  Confidence
#  289438            72           72  March in C C major.mid  Purcell    0.000000
#  289439            72           60  March in C C major.mid  Purcell    0.799487
#  289440            72           59  March in C C major.mid  Purcell    0.799487
#  289441            72           57  March in C C major.mid  Purcell    0.799487
#  289442            72           55  March in C C major.mid  Purcell    0.801118
#  ...              ...          ...                     ...      ...         ...
#  289743            72           40  March in C C major.mid  Purcell    0.823676
#  289744            72           38  March in C C major.mid  Purcell    0.823676
#  289745            72           36  March in C C major.mid  Purcell    0.823676
#  289746            72           36  March in C C major.mid  Purcell    0.823676
#  289747            72           36  March in C C major.mid  Purcell    0.000000
#
#  [310 rows x 9 columns],
#  '24 Caprices Sostenuto Op1No3 E minor.mid':         Unnamed: 0  Unnamed: 0.1   offset                     Chord  \
#  283370      283370        283370    0.000              ['E4', 'E5']
#  283371      283371        283371    2.000            ['F#4', 'F#5']
#  283372      283372        283372    3.000              ['G4', 'G5']
#  283373      283373        283373    4.000  ['B4', 'B3', 'C5', 'C4']
#  283374      283374        283374    4.125  ['B4', 'B3', 'C5', 'C4']
#  ...            ...           ...      ...                       ...
#  284167      284167        284167  249.375             ['F#4', 'E4']
#  284168      284168        284168  249.500             ['F#4', 'E4']
#  284169      284169        284169  249.625             ['F#4', 'E4']
#  284170      284170        284170  249.875             ['F#4', 'E4']
#  284171      284171        284171  250.000             ['F#4', 'E4']
#
#          HighestPitch  LowestPitch                                      file  \
#  283370            76           64  24 Caprices Sostenuto Op1No3 E minor.mid
#  283371            78           66  24 Caprices Sostenuto Op1No3 E minor.mid
#  283372            79           67  24 Caprices Sostenuto Op1No3 E minor.mid
#  283373            72           59  24 Caprices Sostenuto Op1No3 E minor.mid
#  283374            72           59  24 Caprices Sostenuto Op1No3 E minor.mid
#  ...              ...          ...                                       ...
#  284167            66           64  24 Caprices Sostenuto Op1No3 E minor.mid
#  284168            66           64  24 Caprices Sostenuto Op1No3 E minor.mid
#  284169            66           64  24 Caprices Sostenuto Op1No3 E minor.mid
#  284170            66           64  24 Caprices Sostenuto Op1No3 E minor.mid
#  284171            66           64  24 Caprices Sostenuto Op1No3 E minor.mid
#
#          Composer  Confidence
#  283370  Paganini    0.813040
#  283371  Paganini    0.813040
#  283372  Paganini    0.813040
#  283373  Paganini    0.813040
#  283374  Paganini    0.813040
#  ...          ...         ...
#  284167  Paganini    0.638274
#  284168  Paganini    0.638274
#  284169  Paganini    0.638274
#  284170  Paganini    0.638274
#  284171  Paganini    0.638274
#
#  [802 rows x 9 columns],
#  'The Fairy Queen Second Musick Rondeau-Maestoso Z629 Bb major.mid':         Unnamed: 0  Unnamed: 0.1  offset                        Chord  \
#  305393      305393        305393     0.0   ['D5', 'A#4', 'F4', 'A#2']
#  305394      305394        305394     0.5    ['D5', 'A#4', 'F4', 'A2']
#  305395      305395        305395     1.0   ['D5', 'A#4', 'F4', 'A#2']
#  305396      305396        305396     1.5    ['D5', 'A#4', 'F4', 'C3']
#  305397      305397        305397     2.0    ['D5', 'A#4', 'F4', 'D3']
#  ...            ...           ...     ...                          ...
#  305640      305640        305640   139.0   ['A#4', 'G4', 'G3', 'D#3']
#  305641      305641        305641   139.5    ['C5', 'G4', 'G3', 'D#3']
#  305642      305642        305642   140.0     ['D5', 'F4', 'A3', 'F3']
#  305643      305643        305643   140.5    ['C5', 'D#4', 'A3', 'F3']
# ...
#  271607            62           45  Missa Pontificalis Kyrie D minor.mid
#  271608            61           45  Missa Pontificalis Kyrie D minor.mid
#  271609            62           38  Missa Pontificalis Kyrie D minor.mid
#
#         Composer  Confidence
#  271543   Perosi    0.794693
#  271544   Perosi    0.866731
#  271545   Perosi    0.866731
#  271546   Perosi    0.866731
#  271547   Perosi    0.880415
#  271548   Perosi    0.892288
#  271549   Perosi    0.892288
#  271550   Perosi    0.892288
#  271551   Perosi    0.892288
#  271552   Perosi    0.892288
#  271553   Perosi    0.892288
#  271554   Perosi    0.892288
#  271555   Perosi    0.892288
#  271556   Perosi    0.892288
#  271557   Perosi    0.892288
#  271558   Perosi    0.892288
#  271559   Perosi    0.892288
#  271560   Perosi    0.872884
#  271561   Perosi    0.872884
#  271562   Perosi    0.889780
#  271563   Perosi    0.889780
#  271564   Perosi    0.889780
#  271565   Perosi    0.889780
#  271566   Perosi    0.889780
#  271567   Perosi    0.889780
#  271568   Perosi    0.889780
#  271569   Perosi    0.889780
#  271570   Perosi    0.889780
#  271571   Perosi    0.889780
#  271572   Perosi    0.889780
#  271573   Perosi    0.889780
#  271574   Perosi    0.889780
#  271575   Perosi    0.889780
#  271576   Perosi    0.861325
#  271577   Perosi    0.861325
#  271578   Perosi    0.861325
#  271579   Perosi    0.861325
#  271580   Perosi    0.861325
#  271581   Perosi    0.861325
#  271582   Perosi    0.859628
#  271583   Perosi    0.859628
#  271584   Perosi    0.859628
#  271585   Perosi    0.859628
#  271586   Perosi    0.859628
#  271587   Perosi    0.859628
#  271588   Perosi    0.871549
#  271589   Perosi    0.871549
#  271590   Perosi    0.871549
#  271591   Perosi    0.871549
#  271592   Perosi    0.871549
#  271593   Perosi    0.899368
#  271594   Perosi    0.920396
#  271595   Perosi    0.960542
#  271596   Perosi    0.960542
#  271597   Perosi    0.960542
#  271598   Perosi    0.960542
#  271599   Perosi    0.960542
#  271600   Perosi    0.960542
#  271601   Perosi    0.960542
#  271602   Perosi    0.960542
#  271603   Perosi    0.960542
#  271604   Perosi    0.960542
#  271605   Perosi    0.960542
#  271606   Perosi    0.960542
#  271607   Perosi    0.956682
#  271608   Perosi    0.946355
#  271609   Perosi    0.945678  ,
#  'Stabat Mater 8 Allegro Fac ut ardeat... -s, ct- G minor.mid':         Unnamed: 0  Unnamed: 0.1  offset  \
#  254384      254384        254384     0.0
#  254385      254385        254385     1.0
#  254386      254386        254386     2.0
#  254387      254387        254387     3.0
#  254388      254388        254388     4.0
#  ...            ...           ...     ...
#  255337      255337        255337   565.5
#  255338      255338        255338   566.0
#  255339      255339        255339   567.0
#  255340      255340        255340   567.5
#  255341      255341        255341   568.0
#
#                                          Chord  HighestPitch  LowestPitch  \
#  254384                                 ['D5']            74           74
#  254385                          ['D5', 'A#4']            74           70
#  254386                           ['D5', 'A4']            74           69
#  254387                           ['D5', 'G4']            74           67
#  254388                          ['D#5', 'C5']            75           72
#  ...                                       ...           ...          ...
#  255337                           ['C2', 'C3']            48           36
#  255338        ['D4', 'F#4', 'A4', 'D2', 'D3']            69           38
#  255339                    ['F#5', 'D2', 'D3']            78           38
#  255340                           ['D2', 'D3']            50           38
#  255341  ['G4', 'A#4', 'G5', 'G2', 'D3', 'G3']            79           43
#
#                                                       file   Composer  \
#  254384  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  254385  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  254386  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  254387  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  254388  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  ...                                                   ...        ...
#  255337  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  255338  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  255339  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  255340  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#  255341  Stabat Mater 8 Allegro Fac ut ardeat... -s, ct...  Pergolesi
#
#          Confidence
#  254384    0.777546
#  254385    0.777546
#  254386    0.788484
#  254387    0.794445
#  254388    0.794445
#  ...            ...
#  255337    0.951710
#  255338    0.951710
#  255339    0.951710
#  255340    0.951710
#  255341    0.951710
#
#  [958 rows x 9 columns],
#  'The Fairy Queen Act I Song Now Winter Comes Slowly Z629 A minor.mid':        Unnamed: 0  Unnamed: 0.1  offset                      Chord  \
#  14207       14207         14207    0.00                     ['A2']
#  14208       14208         14208    4.00               ['A5', 'A2']
#  14209       14209         14209    6.00                    ['G#5']
#  14210       14210         14210   10.00                     ['G5']
#  14211       14211         14211   12.00                    ['F#5']
#  ...           ...           ...     ...                        ...
#  14414       14414         14414  266.00         ['A3', 'A4', 'E4']
#  14415       14415         14415  267.00   ['A3', 'A4', 'E4', 'G3']
#  14416       14416         14416  268.00  ['A3', 'A4', 'E4', 'F#3']
#  14417       14417         14417  268.75        ['A4', 'E4', 'F#3']
#  14418       14418         14418  269.00         ['A4', 'E4', 'E3']
#
#         HighestPitch  LowestPitch  \
#  14207            45           45
#  14208            81           45
#  14209            80           80
#  14210            79           79
#  14211            78           78
#  ...             ...          ...
#  14414            69           57
#  14415            69           55
#  14416            69           54
#  14417            69           54
#  14418            69           52
#
#                                                      file Composer  Confidence
#  14207  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.000000
#  14208  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.496739
#  14209  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.496739
#  14210  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.544711
#  14211  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.544711
#  ...                                                  ...      ...         ...
#  14414  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.931121
#  14415  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.917157
#  14416  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.882025
#  14417  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.000000
#  14418  The Fairy Queen Act I Song Now Winter Comes Sl...  Purcell    0.000000
#
#  [212 rows x 9 columns],
#  'Toccata C major.mid':        Unnamed: 0  Unnamed: 0.1  offset                           Chord  \
#  33213       33213         33213    0.00              ['F3', 'A3', 'C4']
#  33214       33214         33214    0.25        ['F4', 'F3', 'A3', 'C4']
#  33215       33215         33215    0.50        ['G4', 'F3', 'A3', 'C4']
#  33216       33216         33216    0.75        ['A4', 'F3', 'A3', 'C4']
#  33217       33217         33217    1.00        ['G4', 'F3', 'A3', 'C4']
#  ...           ...           ...     ...                             ...
#  33967       33967         33967  348.25        ['F4', 'F5', 'A4', 'C5']
#  33968       33968         33968  348.75  ['C3', 'F5', 'F4', 'A4', 'C5']
#  33969       33969         33969  349.25  ['F2', 'F5', 'F4', 'A4', 'C5']
#  33970       33970         33970  351.25        ['F5', 'F4', 'C5', 'F2']
#  33971       33971         33971  351.75              ['F5', 'F4', 'F2']
#
#         HighestPitch  LowestPitch                 file  Composer  Confidence
#  33213            60           53  Toccata C major.mid  Pasquini    0.000000
#  33214            65           53  Toccata C major.mid  Pasquini    0.000000
#  33215            67           53  Toccata C major.mid  Pasquini    0.000000
#  33216            69           53  Toccata C major.mid  Pasquini    0.000000
#  33217            67           53  Toccata C major.mid  Pasquini    0.000000
#  ...             ...          ...                  ...       ...         ...
#  33967            77           65  Toccata C major.mid  Pasquini    0.930889
#  33968            77           48  Toccata C major.mid  Pasquini    0.930889
#  33969            77           41  Toccata C major.mid  Pasquini    0.856586
#  33970            77           41  Toccata C major.mid  Pasquini    0.000000
#  33971            77           41  Toccata C major.mid  Pasquini    0.000000
#
#  [759 rows x 9 columns],
#  'Ciacona in D- for organ D minor.mid':        Unnamed: 0  Unnamed: 0.1   offset                      Chord  \
#  75184       75184         75184    0.000         ['D2', 'A3', 'F4']
#  75185       75185         75185    1.000         ['D2', 'D4', 'F3']
#  75186       75186         75186    2.000         ['D2', 'F4', 'A3']
#  75187       75187         75187    3.000         ['E2', 'E4', 'G3']
#  75188       75188         75188    4.000        ['E2', 'C#4', 'E3']
#  ...           ...           ...      ...                        ...
#  76545       76545         76545  407.250  ['A2', 'E4', 'C#4', 'G3']
#  76546       76546         76546  407.375  ['A2', 'F4', 'C#4', 'G3']
#  76547       76547         76547  407.500  ['A2', 'D4', 'C#4', 'G3']
#  76548       76548         76548  407.750  ['A2', 'E4', 'C#4', 'G3']
#  76549       76549         76549  408.000        ['D2', 'F#3', 'D4']
#
#         HighestPitch  LowestPitch                                 file  \
#  75184            65           38  Ciacona in D- for organ D minor.mid
#  75185            62           38  Ciacona in D- for organ D minor.mid
#  75186            65           38  Ciacona in D- for organ D minor.mid
#  75187            64           40  Ciacona in D- for organ D minor.mid
#  75188            61           40  Ciacona in D- for organ D minor.mid
#  ...             ...          ...                                  ...
#  76545            64           45  Ciacona in D- for organ D minor.mid
#  76546            65           45  Ciacona in D- for organ D minor.mid
#  76547            62           45  Ciacona in D- for organ D minor.mid
#  76548            64           45  Ciacona in D- for organ D minor.mid
#  76549            62           38  Ciacona in D- for organ D minor.mid
#
#          Composer  Confidence
#  75184  Pachelbel    0.818906
#  75185  Pachelbel    0.818906
#  75186  Pachelbel    0.824763
#  75187  Pachelbel    0.824763
#  75188  Pachelbel    0.824763
#  ...          ...         ...
#  76545  Pachelbel    0.000000
#  76546  Pachelbel    0.000000
#  76547  Pachelbel    0.000000
#  76548  Pachelbel    0.000000
#  76549  Pachelbel    0.000000
#
#  [1366 rows x 9 columns],
#  'Nina, Canzonetta- G minor.mid':         Unnamed: 0  Unnamed: 0.1   offset                            Chord  \
#  213922      213922        213922    3.000                           ['G4']
#  213923      213923        213923    3.500                          ['A#4']
#  213924      213924        213924    4.000        ['D5', 'G3', 'A#3', 'G2']
#  213925      213925        213925    4.125        ['D5', 'A#3', 'G3', 'G2']
#  213926      213926        213926    4.500  ['D5', 'D4', 'G3', 'A#3', 'G2']
#  ...            ...           ...      ...                              ...
#  214445      214445        214445  245.000              ['G4', 'A#3', 'G2']
#  214446      214446        214446  245.875                    ['G4', 'A#3']
#  214447      214447        214447  246.000                    ['G4', 'A#3']
#  214448      214448        214448  246.875                           ['G4']
#  214449      214449        214449  248.000                           ['G4']
#
#          HighestPitch  LowestPitch                           file   Composer  \
#  213922            67           67  Nina, Canzonetta- G minor.mid  Pergolesi
#  213923            70           70  Nina, Canzonetta- G minor.mid  Pergolesi
#  213924            74           43  Nina, Canzonetta- G minor.mid  Pergolesi
#  213925            74           43  Nina, Canzonetta- G minor.mid  Pergolesi
#  213926            74           43  Nina, Canzonetta- G minor.mid  Pergolesi
#  ...              ...          ...                            ...        ...
#  214445            67           43  Nina, Canzonetta- G minor.mid  Pergolesi
#  214446            67           58  Nina, Canzonetta- G minor.mid  Pergolesi
#  214447            67           58  Nina, Canzonetta- G minor.mid  Pergolesi
#  214448            67           67  Nina, Canzonetta- G minor.mid  Pergolesi
#  214449            67           67  Nina, Canzonetta- G minor.mid  Pergolesi
#
#          Confidence
#  213922    0.000000
#  213923    0.000000
#  213924    0.000000
#  213925    0.000000
#  213926    0.000000
#  ...            ...
#  214445    0.764742
#  214446    0.764742
#  214447    0.764742
#  214448    0.764742
#  214449    0.719372
#
#  [528 rows x 9 columns],
#  '24 Caprices Posato Op1No15 E minor.mid':         Unnamed: 0  Unnamed: 0.1  offset               Chord  HighestPitch  \
#  192794      192794        192794    0.00        ['E4', 'E5']            76
#  192795      192795        192795    0.50      ['F#4', 'F#5']            78
#  192796      192796        192796    1.00        ['G4', 'G5']            79
#  192797      192797        192797    1.75        ['B4', 'B5']            83
#  192798      192798        192798    2.00        ['A4', 'A5']            81
#  ...            ...           ...     ...                 ...           ...
#  193556      193556        193556  159.50        ['B4', 'B3']            71
#  193557      193557        193557  160.00  ['E4', 'B4', 'E5']            76
#  193558      193558        193558  160.50  ['G5', 'E4', 'B4']            79
#  193559      193559        193559  161.00  ['B5', 'E4', 'B4']            83
#  193560      193560        193560  161.50  ['E4', 'B4', 'E5']            76
#
#          LowestPitch                                    file  Composer  \
#  192794           64  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  192795           66  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  192796           67  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  192797           71  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  192798           69  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  ...             ...                                     ...       ...
#  193556           59  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  193557           64  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  193558           64  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  193559           64  24 Caprices Posato Op1No15 E minor.mid  Paganini
#  193560           64  24 Caprices Posato Op1No15 E minor.mid  Paganini
#
#          Confidence
#  192794    0.863859
#  192795    0.863859
#  192796    0.863859
#  192797    0.863859
#  192798    0.863859
#  ...            ...
#  193556    0.748349
#  193557    0.748349
#  193558    0.748349
#  193559    0.748349
#  193560    0.000000
#
#  [767 rows x 9 columns]}
